# %% [markdown]
# # 2018_02_20-1pos2neg
#
# electrode 1 positive
# electrode 2 negative

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from loadLvm import *
from loadRadEye import *
# %matplotlib inline

# %%
with open('data_dir.txt', 'r') as rfp:
    data_dir = rfp.read()
    
data_dir
# Out:
# '../../../Data/Lens Test Measurements'

# %%
fNamelvm = data_dir+'/2018_02_20-1pos2neg.lvm'
fNamelvm2 = data_dir+'/2018_02_20-1pos2neg_2nd.lvm'
fNameRadEye = data_dir+'/2018_02_20-1pos2neg.log'
fNameRadEye2 = data_dir+'/2018_02_20-1pos2neg_2nd.log'
dataLVM = loadlvm_electrostaticlenstests(fNamelvm)
dataLVM2 = loadlvm_electrostaticlenstests(fNamelvm2)
dataLVM = dataLVM.append(dataLVM2)
dataRADEYE = load_radeyeg20(fNameRadEye)
dataRADEYE2 = load_radeyeg20(fNameRadEye2)
dataRADEYE = dataRADEYE.append(dataRADEYE2)

# %%
fs = 15

fig, ax = plt.subplots(figsize = (15,7))
ax.plot(dataLVM.time, dataLVM.V1.abs(), lw = 3, label = 'V1');
ax.plot(dataLVM.time, dataLVM.V2.abs(), lw = 3, label = 'V2');
ax.legend(fontsize = fs)
ax.set_xlabel('time', fontsize = fs)
ax.set_ylabel('Voltage [V]', fontsize = fs)
ax.tick_params(axis='both', which='major', labelsize=fs);
ax.xaxis.set_major_formatter(DateFormatter('%H:%M:%S'))
ax1 = ax.twinx()
ax1.plot(dataRADEYE.time, dataRADEYE['Dose Rate'], 'C3', lw = 3);
ax1.set_ylabel(r'I1 [$\mu$Sv/h]', fontsize = fs, color = 'C3')
ax1.set_ylim(ymax = 0.5)
ax1.tick_params('y', colors='C3');
ax1.tick_params(axis='both', which='major', labelsize=fs);
# fig.savefig('2018_02_20_1pos2neg_voltagedose.png')

# %%
fs = 15

fig, ax = plt.subplots(figsize = (15,7))
ax.plot(dataLVM.time, dataLVM.I1.abs(), lw = 3, label = 'I1');
ax.plot(dataLVM.time, dataLVM.I2.abs(), lw = 3, label = 'V2');
ax.legend(fontsize = fs)
ax.set_xlabel('time', fontsize = fs)
ax.set_ylim(ymin = -.1, ymax = 1)
ax.set_ylabel(r'Current [$\mu$I]', fontsize = fs)
ax.tick_params(axis='both', which='major', labelsize=fs);
ax.xaxis.set_major_formatter(DateFormatter('%H:%M:%S'))
ax1 = ax.twinx()
ax1.plot(dataRADEYE.time, dataRADEYE['Dose Rate'], 'C3', lw = 3);
ax1.set_ylabel(r'I1 [$\mu$Sv/h]', fontsize = fs, color = 'C3')
ax1.set_ylim(ymax = 0.5)
ax1.tick_params('y', colors='C3');
ax1.tick_params(axis='both', which='major', labelsize=fs);
