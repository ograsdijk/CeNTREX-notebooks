# %%
import h5py
import copy
import lmfit
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from rich.progress import Progress
from scipy.stats import binned_statistic
from utils.plot_utils import set_fontsize
from utils.hdf_utils import load_measurement_data_devices_attrs

# %%
def ratio_with_error(a,b,σa,σb):
    ratio = a/b
    err = ratio * np.sqrt((σa/a)**2 + (σb/b)**2)
    return ratio, err

# %%
hdf_dir = Path("../data")

# %%
yag_channel = 0
pmt_channel = 1
pd_channel = 2
pdn_channel = 3
shutter_channel = 4
pdrc_channel = 5

# %%
fname = "2021_3_10.hdf"

with h5py.File(hdf_dir / fname, 'r') as f:
    dset_names = list(f.keys())
    for idn, name in enumerate(f.keys()):
        print(f"{idn:<2} <> {name:<60} : {len(f[name]['readout']['PXIe-5171'])}")
# Out:
# 0  <> 1615410429 scan YAG power absorption only                    : 51
# 1  <> 1615410514 scan YAG power absorption only                    : 451
# 2  <> 1615412267 scan P2 F1                                        : 276
# 3  <> 1615412573 scan R0 F1                                        : 276
# 4  <> 1615412928 scan P2 F1 with R0 F1 det with shutter            : 3801
# 5  <> 1615414553 scan P2 F1 with R0 F1 DET and J1 J2 microwaves with shutter : 4161
# 6  <> 1615416368 scan P2 F1 with R0 F1 DET and J1 J2 microwaves 20 dBM with shutter : 1606
# 7  <> 1615417162 find R0 F1                                        : 366
# 8  <> 1615417426 find P2 F1                                        : 791
# 9  <> 1615419450 scan microwave power J1 J2 with R0 F1 DET and P2 F1 RC : 201
# 10 <> 1615419549 scan microwave power J1 J2 with R0 F1 DET and P2 F1 RC : 91
# 11 <> 1615419595 scan microwave power J1 J2 with R0 F1 DET and P2 F1 RC : 4541
# 12 <> 1615420887 scan P2 F1 with R0 F1 DET (30 mW) and J1 J2 microwaves : 3071
# 13 <> 1615422235 scan P2 F1 with R0 F1 DET (10 mW) and J1 J2 microwaves : 1701
# 14 <> 1615422861 scan R0 F1 (10 mW) with P2 F1 RC  and J1 J2 microwaves : 1721
# 15 <> 1615423512 scan R0 F1 (5 mW) with P2 F1 RC  and J1 J2 microwaves : 1701
# 16 <> 1615424243 scan R0 F1 (1.2 mW) with P2 F1 RC  and J1 J2 microwaves : 2381

# %% [markdown]
# # Scan YAG power

# %%
dset_name = dset_names[1]
devices = ()

# %%
slice_flm  = np.s_[100:250]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
scan_parameter = "PXIe5171 DummyFunc"

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.hist(np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]), 
        bins = 15);

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < 250
mask_pdn = pdn_data.min(axis = 1) < 19000

mask = mask_yag | mask_pdn | mask_abs

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]


absorption_integral = np.trapz(norm_data_norm[:, slice_absi])

# %%
bin_width = np.diff(np.unique(scan_parameters))[0]
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)
stat, bin_edges, bin_number = binned_statistic(scan_parameters, absorption_integral, 
                                               lambda x: np.nanmean(x), bins = bins) 
err, bin_edges, bin_number = binned_statistic(scan_parameters, absorption_integral, 
                                              lambda x: np.nanstd(x)/(np.sqrt(len(x))-1), bins = bins) 

bin_means = bin_edges[:-1]+bin_width/2

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, stat, yerr = err, fmt = '.', ms = 15, linestyle = '-')

ax.set_xlabel('YAG Qswitch delay [μs]')
ax.set_ylabel('absorption integral')
set_fontsize(ax, 14)

# %% [markdown]
# # Scan P2 F1 (40 mW) with R0 F1 detection (60 mW)

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[4]
devices = ()

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed1'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
# pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.hist(np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]), 
        bins = 15);

# %%
yag_cutoff = 250
ptn_cutoff = 19000
abs_cutoff = 7.5
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]

# %%
plt.plot(pmt_data_norm[11])

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
m = bin_means < 330
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], results[0][0][m], yerr = results[0][1][m], fmt = '.', label = 'RC on')
ax.errorbar(bin_means[m], results[1][0][m], yerr = results[1][1][m], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], ratio[m], yerr = err[m], fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %%
ab_traces_per_bin = {}
fl_traces_per_bin = {}
for (_, _, bin_number), (n, ms) in zip(results, [('shutter open', mask_sh_open), ('shutter closed', mask_sh_closed)]):
    fl = {}
    ab = {}
    for idb in np.unique(bin_number):
        b = bin_means[idb-1]
        m = idb == (bin_number - 1)
        fl[b] = pmt_data_norm[ms][m]
        ab[b] = norm_data_norm[ms][m]
    fl_traces_per_bin[n] = fl
    ab_traces_per_bin[n] = ab

# %%
print((bin_means < 328).sum())

fig, axes = plt.subplots(nrows = 11, ncols = 3, figsize = (15,25))
axes = axes.flatten()

ratio_bins = np.linspace(1,10,15)

for ax, b in zip(axes, bin_means[bin_means < 328]):
    fl_o = fl_traces_per_bin['shutter open'][b]
    fl_c = fl_traces_per_bin['shutter closed'][b]
    ab_o = ab_traces_per_bin['shutter open'][b]
    ab_c = ab_traces_per_bin['shutter closed'][b]
    m_nan = ~((np.isnan(fl_o.mean(axis = 1))) | (np.isnan(fl_c.mean(axis = 1))))
    m = m_nan
    fl_o = fl_o[m]
    fl_c = fl_c[m]
    ab_o = ab_o[m]
    ab_c = ab_c[m]

    fl_oi = np.trapz(fl_o[:, slice_fli], axis = 1)
    fl_ci = np.trapz(fl_c[:, slice_fli], axis = 1)
    ab_oi = np.trapz(ab_o[:, slice_absi], axis = 1)
    ab_ci = np.trapz(ab_c[:, slice_absi], axis = 1) 
    
    r = (fl_oi/ab_oi)/(fl_ci/ab_ci)

    ax.hist((fl_oi/ab_oi)/(fl_ci/ab_ci), bins = ratio_bins)
    ax.axvline(r.mean(), color = 'C3', lw = 3)
    ax.text(0.75, 0.9, f"{b} MHz\n {r.mean():.1f}", transform = ax.transAxes, ha = 'center', va = 'top', fontsize = 13)
    set_fontsize(ax, 14)
# Out:
# 33
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: Mean of empty slice.
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\numpy\core\_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: RuntimeWarning: Mean of empty slice.

# %% [markdown]
# # Scan P2 F1 (40 mW) with R0 F1 detection (60 mW) and J1 J2 microwaves (30 dBm)

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[5]
devices = ()

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed1'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
# pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data
# Out:
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in true_divide
#   if sys.path[0] == '':

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

dat = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis])
dat = dat[~np.isnan(dat)]
fig, ax = plt.subplots(figsize = (8,5))
ax.hist(dat, bins = 15);
# Out:
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in subtract
#   after removing the cwd from sys.path.

# %%
yag_cutoff = 250
ptn_cutoff = 20000
abs_cutoff = 5
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]
# Out:
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in subtract

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
m = (bin_means < 330) & (bin_means > 310)
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], results[0][0][m], yerr = results[0][1][m], fmt = '.', label = 'RC on')
ax.errorbar(bin_means[m], results[1][0][m], yerr = results[1][1][m], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], ratio[m], yerr = err[m], fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %% [markdown]
# # Scan P2 F1 (40 mW) with R0 F1 detection (60 mW) and J1 J2 microwaves (20 dBm)

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[6]
devices = ()

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed1'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
# pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

dat = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis])
dat = dat[~np.isnan(dat)]
fig, ax = plt.subplots(figsize = (8,5))
ax.hist(dat, bins = 15);

# %%
yag_cutoff = 250
ptn_cutoff = 20000
abs_cutoff = 8
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
m = (bin_means < 330) & (bin_means > 310)
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], results[0][0][m], yerr = results[0][1][m], fmt = '.', label = 'RC on')
ax.errorbar(bin_means[m], results[1][0][m], yerr = results[1][1][m], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means[m], ratio[m], yerr = err[m], fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %% [markdown]
# # Scan microwave powers with P2 F1 RC (40 mW) with R0 F1 DET (60 mW)

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[11]
devices = ()

# %%
scan_parameter = 'SynthHD Pro SetPower'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdrc_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.hist(np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]), 
        bins = 15);

# %%
yag_cutoff = 250
ptn_cutoff = 19000
abs_cutoff = 8
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('μ power fng [dBm]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('μ power fng [dBm]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %% [markdown]
# # Scan P2 F1 (40 mW) with R0 F1 detection (30 mW) and J1 J2 microwaves (30 dBm)

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[12]
devices = ()

# %%
dset_name
# Out:
# '1615420887 scan P2 F1 with R0 F1 DET (30 mW) and J1 J2 microwaves'

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed1'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdrc_data.mean(axis = 1))

dat = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis])
dat = dat[~np.isnan(dat)]
fig, ax = plt.subplots(figsize = (8,5))
ax.hist(dat, bins = 15);

# %%
# custom mask to ensure removal or part where RC laser got unlocked
m_custom = ~np.ones(len(pmt_data), dtype = bool)
m_custom[1100:1450] = True

# %%
yag_cutoff = 250
ptn_cutoff = 20000
abs_cutoff = 7.5
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl | m_custom

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %%
bin_means_30, ratio_30, err_30 = bin_means, ratio, err

# %% [markdown]
# # Scan P2 F1 (40 mW) with R0 F1 detection (10 mW) and J1 J2 microwaves (30 dBm)
#
# From here the temperature in the lab started changing by 2C, so the RC power dropped (see PD RC) and the frequencies shifted.

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_name = dset_names[13]
devices = ()

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed1'

# %%
pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

norm_data = -pd_data/pdn_data

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdn_data.mean(axis = 1))

fig, ax = plt.subplots(figsize = (8,5))
ax.plot(pdrc_data.mean(axis = 1))

dat = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis])
dat = dat[~np.isnan(dat)]
fig, ax = plt.subplots(figsize = (8,5))
ax.hist(dat, bins = 15);

# %%
yag_cutoff = 250
ptn_cutoff = 20000
abs_cutoff = 7.5
fl_cutoff = -5000

# %%
pmt_data_norm = pmt_data.copy()
norm_data_norm = norm_data.copy()

mask_yag = yag_data.max(axis = 1) < yag_cutoff
mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

mask = mask_yag | mask_pdn | mask_abs | mask_fl

norm_data_norm[mask] = np.nan
norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

pmt_data_norm[mask] = np.nan
pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]

# %%
fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

mask_sh_open = shutter_data.max(axis = 1) > 10000
mask_sh_closed = ~mask_sh_open

bin_width = np.diff(np.unique(scan_parameters)).min()
bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

results = []
for m in [mask_sh_open, mask_sh_closed]:
    stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
    err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
    results.append((stat, err, bin_number))
    
bin_means = bin_edges[:-1]+bin_width/2

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, results[0][0], yerr = results[0][1], fmt = '.', label = 'RC on')
ax.errorbar(bin_means, results[1][0], yerr = results[1][1], fmt = '.', label = 'RC off')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('normalized signal [arb.]')

ax.grid(True)

set_fontsize(ax, 14)

ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])

fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.')

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %% [markdown]
# ### Plot ratios for 30 mW and 10 mW in a single plot

# %%
fig, ax = plt.subplots(figsize = (8,5))
ax.errorbar(bin_means_30, ratio_30, yerr = err_30, fmt = '.', label = '30 mW R0 F1')
ax.errorbar(bin_means, ratio, yerr = err, fmt = '.', label = '10 mW R0 F1')

ax.legend(fontsize = 14)

ax.set_xlabel('IR frequency [MHz]')
ax.set_ylabel('ratio')

ax.grid(True)

set_fontsize(ax, 14)

# %% [markdown]
# # Scan R0 F1 at various powers with P2 F1 RC (40 mW) and J1 J2 microwaves (30 dBm)
#
# Temperature in the lab still changing

# %%
slice_flm  = np.s_[:150]
slice_absm = np.s_[-500:]
slice_fli  = np.s_[100:]
slice_absi = np.s_[10:]

# %%
dset_names_scans = dset_names[14:]
devices = ()
dset_names_scans
# Out:
# ['1615422861 scan R0 F1 (10 mW) with P2 F1 RC  and J1 J2 microwaves',
#  '1615423512 scan R0 F1 (5 mW) with P2 F1 RC  and J1 J2 microwaves',
#  '1615424243 scan R0 F1 (1.2 mW) with P2 F1 RC  and J1 J2 microwaves']

# %%
scan_parameter = 'Laser Lock 1 SetLockPointSeed2'

yag_cutoff = 250
ptn_cutoff = 14000
abs_cutoff = 7.5
fl_cutoff = -5000

# %%
analyzed_data = []
for dset_name in dset_names_scans:
    pxie, pxie_time, pxie_attrs, data_devices = load_measurement_data_devices_attrs(hdf_dir / fname, dset_name, devices)

    yag_data = np.array([pxie[idx][:,yag_channel] for idx in range(1,len(pxie)+1)])
    pmt_data = -np.array([pxie[idx][:,pmt_channel].astype(float) for idx in range(1,len(pxie)+1)])
    pd_data = np.array([pxie[idx][:,pd_channel].astype(float) for idx in range(1,len(pxie)+1)])
    pdn_data = np.array([pxie[idx][:,pdn_channel].astype(float) for idx in range(1,len(pxie)+1)])
    shutter_data = np.array([pxie[idx][:,shutter_channel].astype(float) for idx in range(1,len(pxie)+1)])
    pdrc_data = np.array([pxie[idx][:,pdrc_channel].astype(float) for idx in range(1,len(pxie)+1)])

    scan_parameters = np.array([float(pxie_attrs[idx][scan_parameter]) for idx in range(1,len(pxie)+1)])

    norm_data = -pd_data/pdn_data
    
    fig, ax = plt.subplots(figsize = (8,5))
    ax.plot(pdn_data.mean(axis = 1))

    fig, ax = plt.subplots(figsize = (8,5))
    ax.plot(pdrc_data.mean(axis = 1))

    dat = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis])
    dat = dat[~np.isnan(dat)]
    dat = dat[~np.isinf(dat)]
    fig, ax = plt.subplots(figsize = (8,5))
    ax.hist(dat, bins = 15);
    
    pmt_data_norm = pmt_data.copy()
    norm_data_norm = norm_data.copy()

    mask_yag = yag_data.max(axis = 1) < yag_cutoff
    mask_pdn = pdn_data.min(axis = 1) < ptn_cutoff
    mask_abs = np.trapz(norm_data[:,slice_absi] - norm_data[:,slice_absm].mean(axis = 1)[:, np.newaxis]) < abs_cutoff
    mask_fl = np.trapz(pmt_data[:,slice_fli] - pmt_data[:,slice_flm].mean(axis = 1)[:, np.newaxis]) < fl_cutoff

    mask = mask_yag | mask_pdn | mask_abs | mask_fl

    norm_data_norm[mask] = np.nan
    norm_data_norm -= norm_data_norm[:,slice_absm].mean(axis = 1)[:, np.newaxis]

    pmt_data_norm[mask] = np.nan
    pmt_data_norm -= pmt_data_norm[:,slice_flm].mean(axis = 1)[:, np.newaxis]
    
    fluorescence_integral = np.trapz(pmt_data_norm[:,slice_fli], axis = 1)
    absorption_integral = np.trapz(norm_data_norm[:,slice_absi], axis = 1)

    mask_sh_open = shutter_data.max(axis = 1) > 10000
    mask_sh_closed = ~mask_sh_open

    bin_width = np.diff(np.unique(scan_parameters)).min()
    bins = np.arange(np.unique(scan_parameters).min()-bin_width/2, np.unique(scan_parameters).max()+bin_width, bin_width)

    results = []
    for m in [mask_sh_open, mask_sh_closed]:
        stat, bin_edges, bin_number = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanmean(x), bins = bins)
        err, _, _ = binned_statistic(scan_parameters[m], (fluorescence_integral/absorption_integral)[m], lambda x: np.nanstd(x)/np.sqrt(len(x)-1), bins = bins)
        results.append((stat, err, bin_number))

    bin_means = bin_edges[:-1]+bin_width/2
    
    ratio, err = ratio_with_error(results[0][0], results[1][0], results[0][1], results[1][1])
    
    analyzed_data.append((bin_means, results, ratio, err))
# Out:
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in subtract
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in subtract
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in subtract
# C:\Users\CeNTREX\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in subtract

# %%
powers = [10,5,1.2]

fig, ax = plt.subplots(figsize = (8,5))
for p, (bin_means, _, r, err) in zip(powers, analyzed_data):
    
    m = (bin_means > 312.5) & (bin_means < 318.5)
    
    ax.errorbar(bin_means[m], r[m], yerr = err[m], fmt = '.', label = f'{p:.1f} mW')

    
ax.legend(fontsize = 14)
set_fontsize(ax, 14)

# %%
powers = [10,5,1.2]

fig, ax = plt.subplots(figsize = (8,5))
for p, (bin_means, results, _, _) in zip(powers, analyzed_data):
    stat, err, _ = results[-1]
    ax.errorbar(bin_means, stat, yerr = err, fmt = '.', label = f"{p:.1f} mW")

    
ax.legend(fontsize = 14)
set_fontsize(ax, 14)

# %%
powers = [10,5,1.2]

fig, ax = plt.subplots(figsize = (8,5))
for p, (bin_means, results, _, _) in zip(powers, analyzed_data):
    stat, err, _ = results[0]
    ax.errorbar(bin_means, stat, yerr = err, fmt = '.', label = f"{p:.1f} mW")

    
ax.legend(fontsize = 14)
set_fontsize(ax, 14)
