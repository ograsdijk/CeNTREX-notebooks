# %%
import numpy as np
from utils.binning_utils import bin_dataset_switching
from utils.plot_utils import plot_binned_dataset_switching

# %%
# %%html
# <style>
#     table {
#         display: inline-block
#     }
# </style>
# Out:
# <style>
#     table {
#         display: inline-block
#     }
# </style>

# %% [markdown]
# # Measurements 20-2-2020
#
# ## R0 F1 detection, P2 F2 rotational cooling
# Switching rotational cooling laser polarization.
#
# Single passed the detection light with a single prism. Detection light modulated with modulator (QUBIG AM7-UV, S/N: KA1059), only 0.6$\pi$ modulation.
#
# Multipassed the rotational cooling light with two prisms.
#
# PMT is set to 1 kV, 2x factor 5 amplification stages on SRS amplifier, with 10 kHz lowpass filter.
#
# | desc | value |
# |-----|-----|
# |rot cooling pol type | square wave, gated|
# |rot cooling pol switch | 1.69 Mhz|
# |rot cooling light state | on |
# |rot cooling power | 40 mW |
# |detection pol type | resonant, cont. |
# |detection pol switch | 1.562 MHz |
# |detection power | 32 mW |
#
# PXIe-5171 Channels
#
# |ch0  |ch1    |ch2    |
# |------|------|------|
# |trigger  |PMT | rot. cooling pol state|
#
# ch2 pol state
#
# | high| low |
# |-----|-----|
# |switching on|switching off|

# %%
fname = "rotation_cooling.hdf"

# %%
dset_name = "1582239154 check_effect_pol_switching_rot_cooling_peak_P2_F2"
title = "R0 F1 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no pol switching', 1:'pol switching'})

# %% [markdown]
# ## R0 F1 detection, P2 F1 rotational cooling

# %%
dset_name = "1582239993 check_effect_pol_switching_rot_cooling_peak_P2_F1"
title = "R0 F1 detection, P2 F1 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no pol switching', 1:'pol switching'})

# %% [markdown]
# ## R0 F1 detection, P2 F2 rotational cooling

# %%
dset_name = '1582247702 check_pol_switching_rot_cooling_light_rot_cooling_P2_F2_detection_R0_F1'
title = "R0 F1 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no pol switching', 1:'pol switching'})

# %% [markdown]
# # Measurements 27-2-2020
#
# ## R0 F2 detection, P2 F2 rotational cooling
# Switching rotational cooling laser polarization.
#
# Double passed the detection light with a single prism. Detection light modulated with modulator (QUBIG AM7-UV, S/N: KA1059), full $\pi$ modulation.
#
# Multipassed the rotational cooling light with two prisms.
#
# PMT is set to 1 kV, 2x factor 5 amplification stages on SRS amplifier, with 10 kHz lowpass filter.
#
# | desc | value |
# |-----|-----|
# |rot cooling pol type | square wave, gated|
# |rot cooling pol switch | 1.69 Mhz|
# |rot cooling light state | on |
# |rot cooling power | 50 mW |
# |detection pol type | resonant, cont. |
# |detection pol switch | 1.562 MHz |
# |detection power | 29 mW |
#
# PXIe-5171 Channels
#
# |ch0  |ch1    |ch2    |
# |------|------|------|
# |trigger  |PMT | rot. cooling pol state|
#
# ch2 pol state
#
# | high| low |
# |-----|-----|
# |switching on|switching off|

# %%
fname = "rotational_cooling.hdf"
dset_name = '1582833981 polarization_switching_onoff_P2F2_detection_R0F2'
title = "R0 F2 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no pol switching', 1:'pol switching'})
