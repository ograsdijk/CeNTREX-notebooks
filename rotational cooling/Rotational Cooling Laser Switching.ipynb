# %%
import numpy as np
from utils.binning_utils import bin_dataset_switching
from utils.plot_utils import plot_binned_dataset_switching

# %%
# %%html
# <style>
#     table {
#         display: inline-block
#     }
# </style>
# Out:
# <style>
#     table {
#         display: inline-block
#     }
# </style>

# %% [markdown]
# # Switching rotational cooling light
#
# Switching the rotational cooling light on/off with a shutter, shutter state is captured in CH2 of the PXIe-5171 data acquisition.
#
# | high| low |
# |-----|-----|
# |open|closed|
#
# PMT is set to 1 kV, 2x factor 5 amplification stages on SRS amplifier, with 10 kHz lowpass filter.
#
# PXIe-5171 Channels
#
# |ch0  |ch1    |ch2    |
# |------|------|------|
# |trigger  |PMT | polarization or light state|
#
# ## R0 F2 detection, P2 F1 rotational cooling

# %%
fname = "rotation_cooling.hdf"
dset_name = "1582245525 switching_rot_cooling_light_P2_F1_detection_R0_F2"
title = "R0 F2 detection, P2 F1 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['ratios'][0].savefig(title+'_ratio.png', dpi = 300)

# %% [markdown]
# ## R0 F2 detection, P2 F2 rotational cooling

# %%
dset_name = '1582246085 check_effect_pol_switching_light_P2_F2_detection_R0_F2'
title = "R0 F2 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['ratios'][0].savefig(title+'_ratio.png', dpi = 300)

# %% [markdown]
# ## R0 F1 detection, P2 F2 rotational cooling

# %%
dset_name = '1582246569 check_pol_switching_light_P2_F2_detection_R0_F1'
title = "R0 F1 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})
# Out:
# {'trace mean': (<Figure size 576x432 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x140fabbae48>),
#  'trace ratio': (<Figure size 576x432 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x140fac50c48>),
#  'ratios': (<Figure size 576x432 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x140faca1308>),
#  'histogram': (<Figure size 576x432 with 1 Axes>,
#   <matplotlib.axes._subplots.AxesSubplot at 0x140facd7d08>)}

# %% [markdown]
# ## R0 F1 detection, P2 F1 rotational cooling

# %%
dset_name = '1582244846 switch_light_cooling_P2_F1'
title = "R0 F1 detection, P2 F1 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['ratios'][0].savefig(title+'_ratio.png', dpi = 300)

# %% [markdown]
# # Measurements 27-2-2020
#
#
# ## R0 F1 detection, P2 F2 rotational cooling
# Switching rotational cooling light on/off with a shutter.
#
# Double passed the detection light with a single prism. Detection light modulated with modulator (QUBIG AM7-UV, S/N: KA1059).
#
# PMT is set to 1 kV, 2x factor 5 amplification stages on SRS amplifier, with 10 kHz lowpass filter.
#
# | desc | value |
# |-----|-----|
# |rot cooling pol type | square wave, cont.|
# |rot cooling pol switch | 1.69 Mhz|
# |rot cooling light state | switched |
# |rot cooling power | 50 mW |
# |detection pol type | resonant, cont. |
# |detection pol switch | 1.562 MHz |
# |detection power | 29 mW |
#
# PXIe-5171 Channels
#
# |ch0  |ch1    |ch2    |
# |------|------|------|
# |trigger  |PMT | rot. cooling light state|
#
# ch2 shutter state
#
# | high| low |
# |-----|-----|
# |open|closed|

# %%
fname = "rotational_cooling.hdf"
dset_name = '1582832134 switching_light_P2F2_detection_R0F1'
title = "R0 F1 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['ratios'][0].savefig(title+'_ratio.png', dpi = 300)

# %% [markdown]
# ## R0 F2 detection, P2 F2 rotational cooling

# %%
fname = "rotational_cooling.hdf"
dset_name = '1582832887 switch_light_P2F2_detection_R0F2'
title = "R0 F2 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['ratios'][0].savefig(title+'_ratio.png', dpi = 300)

# %% [markdown]
# ## P2 F2 detection, P2 F2 rotational cooling depletion measurement

# %%
fname = "rotational_cooling.hdf"
dset_name = '1582835387 check_depletion_P2_F2_detection_P2_F2_rot_cooling'
title = "P2 F2 detection, P2 F2 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['histogram'][0].savefig(title+'_histogram.png', dpi = 300)

# %% [markdown]
# ## P2 F1 detection, P2 F1 rotational cooling depletion measurement

# %%
fname = "rotational_cooling.hdf"
dset_name = '1582836381 depletion_switching_rot_cooling_P2F1_detection_P2F1'
title = "P2 F1 detection, P2 F1 rotational cooling"

switch_state, bin_state_data, ratio = bin_dataset_switching(fname, dset_name, pmt_channel = 1, switching_channel = 2, threshold = 500)
figures = plot_binned_dataset_switching(bin_state_data, ratio, title = title, switch_labels = {0: 'no rotational cooling', 1:'rotational cooling'})

figures['trace mean'][0].savefig(title+'_trace.png', dpi = 300)
figures['histogram'][0].savefig(title+'_histogram.png', dpi = 300)
